# %%
import json
import pandas as pd
from nltk.corpus import stopwords
import nltk
import re
import time
import datetime
from gensim import corpora, models, similarities, matutils
import os
import operator
import pprint
from sklearn.decomposition import RandomizedPCA, PCA
from scipy import io

# %%
# this is generaed using scrapy
comments = pd.read_json('./data/comments_small.json')
comments
# Out:
#                                author_id author_name  \
# 0             /people/mr-charles-grant-1
# 1            /people/baron-charles-abbot
# 2              /people/mr-george-tierney
# 3              /people/mr-charles-bragge
# 4            /people/baron-charles-abbot
# 5                /people/mr-john-burland
# 6               /people/mr-charles-fox-1
# 7            /people/sir-francis-burdett
# 8            /people/mr-robert-jenkinson
# 9            /people/mr-robert-jenkinson
# 10           /people/mr-robert-jenkinson
# 11            /people/mr-french-laurence
# 12            /people/mr-william-baldwin
# 13                /people/mr-john-curwen
# 14             /people/mr-john-courtenay
# 15            /people/mr-french-laurence
# 16            /people/mr-french-laurence
# 17          /people/mr-william-windham-1
# 18                /people/mr-john-dent-1
# 19            /people/mr-charles-grant-1
# 20             /people/mr-william-dundas
# 21           /people/mr-robert-jenkinson
# 22                /people/mr-john-dent-1
# 23           /people/mr-robert-jenkinson
# 24            /people/mr-william-hanover
# 25             /people/mr-thomas-creevey
# 26                /people/mr-john-dent-1
# 27                /people/mr-john-dent-1
# 28           /people/sir-william-scott-1
# 29     /people/hon-francis-ogilvie-grant
# ...                                  ...         ...
# 1546          /people/mr-richard-ellison
# 1547       /people/mr-samuel-whitbread-2
# 1548       /people/mr-samuel-whitbread-2
# 1549       /people/mr-samuel-whitbread-2
# 1550       /people/mr-samuel-whitbread-2
# 1551          /people/mr-john-calcraft-2
# 1552         /people/mr-spencer-perceval
# 1553         /people/mr-spencer-perceval
# 1554          /people/mr-john-calcraft-2
# 1555         /people/mr-george-johnstone
# 1556         /people/mr-george-johnstone
# 1557         /people/mr-spencer-perceval
# 1558       /people/mr-samuel-whitbread-2
# 1559         /people/mr-spencer-perceval
# 1560         /people/mr-george-johnstone
# 1561            /people/lord-henry-petty
# 1562              /people/mr-john-fuller
# 1563         /people/mr-george-johnstone
# 1564  /people/mr-george-capell-coningsby
# 1565         /people/mr-robert-jenkinson
# 1566             /people/mr-peter-cowper
# 1567        /people/mr-william-grenville
# 1568         /people/mr-robert-jenkinson
# 1569             /people/mr-henry-phipps
# 1570        /people/mr-william-grenville
# 1571         /people/sir-john-wrottesley
# 1572          /people/mr-william-hanover
# 1573         /people/mr-george-spencer-2
# 1574         /people/mr-robert-jenkinson
# 1575          /people/mr-william-hanover
#
#                                                 content             date  \
# 0     begged to be indulged, while he stated in just...  [1803, nov, 25]
# 1     observed that there were two distinct question...  [1803, nov, 25]
# 2     did not think the case of Mr. Grey applicable ...  [1803, nov, 25]
# 3     agreed with his hon. friend (Mr. Tierney) that...  [1803, nov, 25]
# 4     acquainted the House that the House h3d, in ob...  [1803, nov, 22]
# 5     &#x2014;Sir, In rising to second the motion of...  [1803, nov, 22]
# 6     &#x2014;Sir, I do not rise with the intention ...  [1803, nov, 22]
# 7     &#x2014;I do not rise, Sir, for the purpose of...  [1803, nov, 22]
# 8     moved that Lord Walsingham be appointed chairm...  [1803, nov, 22]
# 9     replied, that he was not then prepared to stat...  [1803, dec, 12]
# 10    rose to move the second reading of theIrish Ha...  [1803, dec, 12]
# 11    said that some misapprehension existed about t...  [1803, dec, 12]
# 12    presented a petition from the prisoners confin...  [1803, dec, 12]
# 13    as one who had mistaken the right hon. gent. (...  [1803, dec, 12]
# 14    declared that, he never heard such an extravag...  [1803, dec, 12]
# 15    supported Mr. Windham's arguments. On the subj...  [1803, dec, 12]
# 16    was not satisfied with this comparison, becaus...  [1803, dec, 12]
# 17    denied that he had meant an armed democracy, t...  [1803, dec, 12]
# 18    rose, not to oppose the committal of the bill,...  [1803, dec, 06]
# 19    said, the object of the bill was not to place ...  [1803, dec, 06]
# 20    also supported the bill; and denied there was ...  [1803, dec, 06]
# 21    rose to order. He felt It incumbent on him to ...  [1803, dec, 16]
# 22    moved for leave to bring up a petition from th...  [1803, dec, 01]
# 23    observed, that the noble earl had certainly pu...  [1803, dec, 16]
# 24    then rose and observed, that he entirely concu...  [1803, dec, 16]
# 25    thought it never had been conceived by the inh...  [1803, dec, 01]
# 26    moved, that the petition be referred to a comm...  [1803, dec, 01]
# 27    said, the measure proposed in the petition, ha...  [1803, dec, 01]
# 28    rose to move for leave to bring in a bill to e...  [1803, dec, 01]
# 29    who, on account of his absence on the Waterfor...  [1803, dec, 06]
# ...                                                 ...              ...
# 1546  begged pardon of the house while he performed ...  [1805, oct, 10]
# 1547  hoped it would not be necessary for him to mak...  [1805, oct, 10]
# 1548  again rose, and said, that he thought the most...  [1805, oct, 10]
# 1549  replied, that it was his intention they should...  [1805, oct, 10]
# 1550  said, that on the very first day after the con...  [1805, oct, 10]
# 1551  could not possibly listen in silence to the at...  [1806, jan, 17]
# 1552  adverting to the determination expressed by th...  [1806, jan, 17]
# 1553  explained, that he had not said the noble lord...  [1806, jan, 17]
# 1554  observed, that an hon. gent. (Mr. Montague) se...  [1806, jan, 17]
# 1555  would not have trespassed further on the time ...  [1806, jan, 17]
# 1556  observed, that he would not oppose the vote of...  [1806, jan, 17]
# 1557  said, that every one would allow that it was n...  [1806, jan, 17]
# 1558  observed, that it was his intention at first t...  [1806, jan, 17]
# 1559  said, that his only object had been to obviate...  [1806, jan, 17]
# 1560  wished to know from the Speaker, how far it wa...  [1806, jan, 17]
# 1561  observed, that the same reason, the multitude ...  [1806, jan, 17]
# 1562  hoped that the abstract would at all events be...  [1806, jan, 17]
# 1563  then stated, that he was ready to consent to w...  [1806, jan, 17]
# 1564  rose, to move an address of thanks to his maje...  [1806, jan, 21]
# 1565  pursuant to notice, to move the thanks of the ...  [1806, jan, 28]
# 1566  said, that he did not rise to offer any opposi...  [1806, jan, 21]
# 1567  rose to return thanks to the noble lord, who h...  [1806, jan, 21]
# 1568  expressed his acquiescence in most of the obse...  [1806, jan, 21]
# 1569  complimented the two noble lords on the motive...  [1806, jan, 21]
# 1570  said, that his noble friend seemed to interpre...  [1806, jan, 21]
# 1571  asked whether the allowance to the volunteers ...  [1806, jan, 31]
# 1572  stated, that he did not rise for the purpose o...  [1806, jan, 28]
# 1573  said, he did not recollect any such amendment....  [1806, jan, 28]
# 1574  thought it unusual to word such motions so min...  [1806, jan, 28]
# 1575  took the opportunity to express his very high ...  [1806, jan, 28]
#
#         house
# 0     commons
# 1     commons
# 2     commons
# 3     commons
# 4     commons
# 5     commons
# 6     commons
# 7     commons
# 8       lords
# 9       lords
# 10      lords
# 11    commons
# 12    commons
# 13    commons
# 14    commons
# 15    commons
# 16    commons
# 17    commons
# 18    commons
# 19    commons
# 20    commons
# 21      lords
# 22    commons
# 23      lords
# 24      lords
# 25    commons
# 26    commons
# 27    commons
# 28    commons
# 29    commons
# ...       ...
# 1546  commons
# 1547  commons
# 1548  commons
# 1549  commons
# 1550  commons
# 1551  commons
# 1552  commons
# 1553  commons
# 1554  commons
# 1555  commons
# 1556  commons
# 1557  commons
# 1558  commons
# 1559  commons
# 1560  commons
# 1561  commons
# 1562  commons
# 1563  commons
# 1564    lords
# 1565    lords
# 1566    lords
# 1567    lords
# 1568    lords
# 1569    lords
# 1570    lords
# 1571  commons
# 1572    lords
# 1573    lords
# 1574    lords
# 1575    lords
#
# [1576 rows x 5 columns]

# %%
def clean(text):
    # 2. Remove non-letters
    letters_only = re.sub("[^a-zA-Z]", " ", text)

    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()

    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))

     # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]

    # 6. Join the words back into one string separated by space,
    # and return the result.
    return( " ".join( meaningful_words ))

authors = comments['author_id'].unique()
print(len(authors), "speakers in total")
print()
comments_by_author = []
for author in authors:
    comments_by_author.append(clean(' '.join(comments[comments['author_id']==author]['content'])))
    
corpus = ' '.join(comments_by_author).split(' ')
# Remove words which orrur less thatn twice in the corpus. As these are not duplicated between
# documents they do not contribute to the differences between documents.
# see https://radimrehurek.com/gensim/tut1.html
import collections
counter=collections.Counter(corpus)
corpus_words_non_singleton = [word for word, count in counter.items() if count > 1]

documents = []

print("each document represents one speaker")
print()

for i, doc in enumerate(comments_by_author[:3]):
    start_time = time.time()
    print("processing document %s" % (i + 1), "of %s" % len(comments_by_author))
    doc = doc.split(' ')
    doc = [word for word in doc if word in corpus_words_non_singleton]
    documents.append(doc)
    if start_time is not None:
        print("took %s" % (time.time() - start_time))
        
comments_by_author =  pd.DataFrame(comments_by_author, index=authors , columns=['comments'])
comments_by_author
# Out:
# 170 speakers in total
#
# each document represents one speaker
#
# processing document 1 of 170
# took 0.008413314819335938
# processing document 2 of 170
# took 0.17219781875610352
# processing document 3 of 170
# took 0.40198826789855957
#                                                                              comments
# /people/mr-charles-grant-1          begged indulged stated justification hon membe...
# /people/baron-charles-abbot         observed two distinct questions house consider...
# /people/mr-george-tierney           think case mr grey applicable present instance...
# /people/mr-charles-bragge           agreed hon friend mr tierney proceeding appear...
# /people/mr-john-burland             x sir rising second motion honourable friend f...
# /people/mr-charles-fox-1            x sir rise intention objecting particularly pr...
# /people/sir-francis-burdett         x rise sir purpose disturbing unanimity house ...
# /people/mr-robert-jenkinson         moved lord walsingham appointed chairman commi...
# /people/mr-french-laurence          said misapprehension existed exemptions respec...
# /people/mr-william-baldwin          presented petition prisoners confined debt cou...
# /people/mr-john-curwen              one mistaken right hon gent mr pitt declared s...
# /people/mr-john-courtenay           declared never heard extravagant speech right ...
# /people/mr-william-windham-1        denied meant armed democracy extent alleged sp...
# /people/mr-john-dent-1              rose oppose committal bill call attention hous...
# /people/mr-william-dundas           also supported bill denied truth arguments hon...
# /people/mr-william-hanover          rose observed entirely concurred sentiments no...
# /people/mr-thomas-creevey           thought never conceived inhabitants liverpool ...
# /people/sir-william-scott-1         rose move leave bring bill encourage residence...
# /people/hon-francis-ogilvie-grant   account absence waterford committee ordered at...
# /people/mr-william-plumer           rose moved consequence hon gentleman apology o...
# /people/mr-isaac-corry              moved order day second reading theirish bank r...
# /people/lord-archibald-hamilton     rose pie said see reason restriction payments ...
# /people/mr-john-calcraft-2          professed wish procrastinate business could he...
# /people/mr-daniel-giles             said considered bill new amended lords precise...
# /people/mr-john-sargent             brought report thebank england restriction bil...
# /people/sir-william-elford          called attention house important alteration bi...
# /people/mr-francis-gregor           said mean oppose measure contrary obliged nobl...
# /people/sir-philip-francis          mean oppose motion though enemy every exercise...
# /people/mr-benjamin-hobhouse        brought report committee upon expiring laws re...
# /people/mr-william-grenville        said already expressed surprise bill read seco...
# ...                                                                               ...
# /people/mr-denis-daly               said day received instructions constituents op...
# /people/sir-george-hill             supported motion panegyrised character irish m...
# /people/sir-charles-price           considered duty check progress commerce discou...
# /people/lord-john-thynne            took oaths seat election bath x mr creevey gav...
# /people/mr-charles-chapman          spoke favour original motion said moment enter...
# /people/mr-robert-thornton          warmly approved original motion opinion system...
# /people/mr-thomas-wallace-3         rose express conviction felt lord melville sai...
# /people/mr-charles-moore-1          pronounced bill mere job abandoned members cou...
# /people/sir-john-hippisley          said although taken part proceedings hitherto ...
# /people/mr-claude-scott             stated money much l one proof hon gent extreme...
# /people/sir-andrew-hamond           rose give notice move morrow papers respecting...
# /people/mr-nathaniel-bond           x true name appears upon warrant subscribed wi...
# /people/mr-john-jeffery             poole contended whatever might portion praise ...
# /people/mr-richard-ryder-1          thought topics objected fairly naturally intro...
# /people/mr-francis-brown            said extraordinary report commissioners impres...
# /people/mr-francis-burton           spoke favour bill said house glebe tithes prop...
# /people/mr-john-hutchinson-3        x lords course debate catholic hierarchy pries...
# /people/mr-henry-grattan            rose spoke follows x sir offering house sentim...
# /people/mr-thomas-orde-powlett      formerly held high official situation ireland ...
# /people/sir-john-sinclair-1         entertained great doubts respect propriety bri...
# /people/sir-robert-shaw             member dublin spoke follows although sir wish ...
# /people/mr-david-scott              meant first objected committee case made groun...
# /people/sir-mark-wood               seeing house disposed proceed said longer dela...
# /people/mr-william-garrow           x opinion facts stated would inevitably subjec...
# /people/mr-spencer-perceval         x opinion case mentioned certainly comes withi...
# /people/sir-william-erskine         said laid mind subject devising might best mod...
# /people/mr-william-wickham-1        accordingly addressed house hon member adverti...
# /people/mr-samuel-thornton          rose consequence allusion made night preceding...
# /people/mr-george-capell-coningsby  rose move address thanks majesty speech read l...
# /people/mr-peter-cowper             said rise offer opposition motion lordships an...
#
# [170 rows x 1 columns]

# %%
# create the dictionary object used by gensim

# repeat the process using memory efficiant method and not loading corpus into memory
def tokenize_raw(doc):
    letters_only = re.sub("[^a-zA-Z]", " ", doc)
    return letters_only.lower().split()

DICT_PATH = './data/hansard_corpus.dict'
if os.path.exists(DICT_PATH):
    # load dictionary
    dictionary = corpora.Dictionary.load(DICT_PATH)
else:
    # load dictionary
    dictionary = corpora.Dictionary(tokenize_raw(json.loads(line[:-2])['content']) for line in open('../comments_small.json'))
    # remove stop words and words that appear only once
    stop_ids = [dictionary.token2id[stopword] for stopword in stopwords.words("english") if stopword in dictionary.token2id]
    once_ids = [tokenid for tokenid, docfreq in dictionary.dfs.iteritems() if docfreq == 1]
    dictionary.filter_tokens(stop_ids + once_ids) # remove stop words and words that appear only once
    dictionary.compactify() # remove gaps in id sequence after words that were removed
    dictionary.save(DICT_PATH)

print(dictionary.num_docs, 'documents')
print(len(dictionary.values()), 'unique tokens')

dict_sorted_by_occurances = sorted(dictionary.dfs.items(), key=operator.itemgetter(1))
print('common_words:\n', pprint.pprint({dictionary.get(id):count for id, count in dict_sorted_by_occurances[-30:]}))
dictionary.filter_extremes()
print('common_words:\n', pprint.pprint({dictionary.get(id):count for id, count in dict_sorted_by_occurances[-30:]}))
# Out:
# 315358 documents
# 70996 unique tokens
# {'bill': 83707,
#  'case': 59044,
#  'could': 100032,
#  'country': 68190,
#  'gentleman': 71331,
#  'government': 85957,
#  'great': 72976,
#  'hon': 132723,
#  'house': 121332,
#  'lord': 63131,
#  'made': 85462,
#  'member': 84261,
#  'might': 81933,
#  'much': 56994,
#  'must': 59971,
#  'noble': 57951,
#  'one': 94617,
#  'present': 77259,
#  'question': 81435,
#  'right': 81908,
#  'said': 150456,
#  'say': 67151,
#  'state': 58885,
#  'subject': 64425,
#  'thought': 74820,
#  'time': 73383,
#  'upon': 90248,
#  'whether': 70365,
#  'would': 173308,
#  'x': 88314}
# common_words:
#  None
# {None: 150456,
#  'attrition': 74820,
#  'auxiliaries': 63131,
#  'burghley': 64425,
#  'deficiencies': 85957,
#  'establishing': 81435,
#  'glocestershire': 59044,
#  'imitate': 70365,
#  'memorialise': 57951,
#  'percival': 84261,
#  'robust': 56994,
#  'sandgate': 173308,
#  'sizarships': 83707,
#  'tend': 94617,
#  'thefree': 100032}
# common_words:
#  None

# %%
## TOPIC MODELLING - unsupervised clustering of documents

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

CORPUS_PATH = './data/large_files/corpus.mm'

class Corpus(object):
    def __iter__(self):
        for line in open('./data/large_files/comments.json'):
            # assume there's one json per line, remove the comma at the end of the line and only use the 'content' section
            yield dictionary.doc2bow(tokenize_raw(json.loads(line[:-2])['content']))

# try loading from file othewise load from iterator.
if os.path.exists(CORPUS_PATH):
    print('loading existing corpus')
    BOW_corpus = corpora.MmCorpus(CORPUS_PATH)
else:
    print('building corpus')
    BOW_corpus = Corpus()
    corpora.MmCorpus.serialize(CORPUS_PATH, BOW_corpus)

print(BOW_corpus)

# once you have a BOW corpus you can convert it to different model formats

TFIDF = models.TfidfModel(BOW_corpus) # step 1 -- initialize a model
TFIDF_corpus = TFIDF[BOW_corpus]
corpora.MmCorpus.serialize('./data/large_files/tfidf_corpus.mm', TFIDF_corpus)

print(TFIDF_corpus)
#lsi = models.LsiModel(corpus_tfidf, id2word=dictionary, num_topics=) # initialize an LSI transformation

#lsi = models.LsiModel(corpus, id2word=dictionary, num_topics=100)
#corpus_lsi = lsi[corpus_tfidf] # create a double wrapper over the original corpus: bow->tfidf->fold-in-lsi

#lsi.print_topics(5)
# Out:
# loading existing corpus
# MmCorpus(315358 documents, 45481 features, 29827150 non-zero entries)

# %%
# documents in the BOW corpus are sparse vectors where each element represents term_id, count; respectively.
print(BOW_corpus[2])

# %%
print TFIDF_corpus[2]

# %%
# SCIPY can read the matrix format from disk
#from scipy import io
#sparse_corpus = scipy.io.mmread('./data/corpus.mm')

# sparse matrix can also be generated using gensim matrix utils
# https://radimrehurek.com/gensim/tut1.html#compatibility-with-numpy-and-scipy
scipy_csc_matrix = matutils.corpus2csc(TFIDF_corpus)
dense_scipy_TFIDF = scipy_csc_matrix.toarray()

# %%
# Find out what people are speaking about by finding their top tfidf words

corpus = [text.split() for text in comments_by_author['comments'].values]
dictionary = corpora.Dictionary(corpus)
corpus_BOW = [dictionary.doc2bow(doc) for doc in corpus]
TFIDF = models.TfidfModel(corpus_BOW)
corpus_TFIDF = TFIDF[corpus_BOW]
## Get the words with the highest TFIDF
[
    (author, [dictionary.get(id) for id, tfidf_score in sorted(doc_tfidf, key=operator.itemgetter(1))[-10:]])
     for author, doc_tfidf in zip(comments_by_author.index, corpus_TFIDF)
]
# Out:
# [('/people/mr-charles-grant-1',
#   ['dissolved',
#    'weeks',
#    'desiring',
#    'fractional',
#    'depreciate',
#    'deducted',
#    'endless',
#    'committees',
#    'prorogation',
#    'bonds']),
#  ('/people/baron-charles-abbot',
#   ['amendment',
#    'usual',
#    'proclamation',
#    'house',
#    'days',
#    'meeting',
#    'member',
#    'amendments',
#    'consequential',
#    'title']),
#  ('/people/mr-george-tierney',
#   ['lord',
#    'right',
#    'earl',
#    'petition',
#    'petitioners',
#    'trotter',
#    'hon',
#    'st',
#    'gent',
#    'vincent']),
#  ('/people/mr-charles-bragge',
#   ['seventh',
#    'whereby',
#    'w',
#    'journals',
#    'tha',
#    'f',
#    'esq',
#    'preceedings',
#    'grant',
#    'huskisson']),
#  ('/people/mr-john-burland',
#   ['arms',
#    'coasts',
#    'sunk',
#    'europe',
#    'despotism',
#    'france',
#    'boat',
#    'rejoice',
#    'unanimity',
#    'sir']),
#  ('/people/mr-charles-fox-1',
#   ['lord',
#    'volunteers',
#    'roman',
#    'say',
#    'ministers',
#    'may',
#    'right',
#    'hon',
#    'gent',
#    'catholics']),
#  ('/people/sir-francis-burdett',
#   ['petition',
#    'bloomsbury',
#    'thepancras',
#    'seamens',
#    'purports',
#    'byng',
#    'vestry',
#    'ordered',
#    'debtors',
#    'hobhouse']),
#  ('/people/mr-robert-jenkinson',
#   ['country',
#    'lords',
#    'catholics',
#    'lordship',
#    'religion',
#    'force',
#    'earl',
#    'baron',
#    'noble',
#    'lordships']),
#  ('/people/mr-french-laurence',
#   ['sir',
#    'spanish',
#    'catholic',
#    'church',
#    'protestant',
#    'friend',
#    'lateran',
#    'council',
#    'learned',
#    'catholics']),
#  ('/people/mr-william-baldwin',
#   ['punishing',
#    'jan',
#    'dof',
#    'chertsey',
#    'h',
#    'convicts',
#    'cardigan',
#    'dand',
#    'corry',
#    'miscellaneous']),
#  ('/people/mr-john-curwen',
#   ['revenue',
#    'claimant',
#    'isle',
#    'tynwald',
#    'x',
#    'island',
#    'proprietor',
#    'insular',
#    'grace',
#    'keys']),
#  ('/people/mr-john-courtenay',
#   ['distinctions',
#    'assault',
#    'vagance',
#    'queerest',
#    'slake',
#    'hyde',
#    'enrol',
#    'gallery',
#    'democracy',
#    'volunteers']),
#  ('/people/mr-william-windham-1',
#   ['sort',
#    'volunteer',
#    'recruiting',
#    'say',
#    'militia',
#    'men',
#    'system',
#    'volunteers',
#    'force',
#    'army']),
#  ('/people/mr-john-dent-1',
#   ['company',
#    'town',
#    'merchants',
#    'harbour',
#    'batteries',
#    'yearly',
#    'captains',
#    'liverpool',
#    'petition',
#    'loan']),
#  ('/people/mr-william-dundas',
#   ['esq',
#    'returning',
#    'gent',
#    'melville',
#    'extravagancies',
#    'liskeard',
#    'misconduct',
#    'holland',
#    'borough',
#    'parchment']),
#  ('/people/mr-william-hanover',
#   ['fleet',
#    'shipwrights',
#    'amen',
#    'navy',
#    'earl',
#    'yards',
#    'r',
#    'viscount',
#    'noble',
#    'h']),
#  ('/people/mr-thomas-creevey',
#   ['mainwaring',
#    'public',
#    'candians',
#    'candian',
#    'sir',
#    'candia',
#    'debt',
#    'candy',
#    'ceylon',
#    'fordyce']),
#  ('/people/sir-william-scott-1',
#   ['donation',
#    'church',
#    'distribution',
#    'may',
#    'securities',
#    'constitution',
#    'agents',
#    'parties',
#    'prize',
#    'protestant']),
#  ('/people/hon-francis-ogilvie-grant',
#   ['ford',
#    'attend',
#    'misapprehension',
#    'military',
#    'absence',
#    'attendance',
#    'transgress',
#    'misapprehensions',
#    'dundee',
#    'imperious']),
#  ('/people/mr-william-plumer',
#   ['falsely',
#    'corn',
#    'agriculture',
#    'catechising',
#    'stai',
#    'consumers',
#    'consquently',
#    'cere',
#    'bread',
#    'farmer']),
#  ('/people/mr-isaac-corry',
#   ['revenue',
#    'balance',
#    'linen',
#    'exported',
#    'cwt',
#    'duties',
#    'export',
#    'ireland',
#    'hereditary',
#    'crown']),
#  ('/people/lord-archibald-hamilton',
#   ['per',
#    'issues',
#    'evil',
#    'cent',
#    'bank',
#    'paper',
#    'ireland',
#    'currency',
#    'exchange',
#    'restriction']),
#  ('/people/mr-john-calcraft-2',
#   ['presented',
#    'amendments',
#    'militia',
#    'bill',
#    'salt',
#    'ceylon',
#    'morrow',
#    'printed',
#    'ordnance',
#    'powder']),
#  ('/people/mr-daniel-giles',
#   ['act',
#    'exemptions',
#    'accoutred',
#    'hertfordshire',
#    'parliament',
#    'continuance',
#    'breach',
#    'volunteers',
#    'commission',
#    'faith']),
#  ('/people/mr-john-sargent',
#   ['peace',
#    'amendment',
#    'reading',
#    'months',
#    'six',
#    'duration',
#    'conclusion',
#    'restriction',
#    'makes',
#    'thebank']),
#  ('/people/sir-william-elford',
#   ['rankest',
#    'coram',
#    'personsnon',
#    'commended',
#    'intended',
#    'conceiving',
#    'holland',
#    'corn',
#    'thin',
#    'commissioners']),
#  ('/people/mr-francis-gregor',
#   ['commissioner',
#    'commissioners',
#    'rectify',
#    'executing',
#    'meantime',
#    'fund',
#    'detects',
#    'tax',
#    'consolidated',
#    'executed']),
#  ('/people/sir-philip-francis',
#   ['company',
#    'peshwa',
#    'war',
#    'mahrattas',
#    'indian',
#    'bengal',
#    'princes',
#    'scindia',
#    'mahratta',
#    'india']),
#  ('/people/mr-benjamin-hobhouse',
#   ['ordered',
#    'lordship',
#    'expiring',
#    'vincent',
#    'wines',
#    'mr',
#    'monday',
#    'vansittart',
#    'hobhouse',
#    'corry']),
#  ('/people/mr-william-grenville',
#   ['bank',
#    'ireland',
#    'religion',
#    'petitioners',
#    'roman',
#    'paper',
#    'catholic',
#    'noble',
#    'catholics',
#    'lordships']),
#  ('/people/sir-william-young-1',
#   ['disposable',
#    'interior',
#    'famel',
#    'militia',
#    'africa',
#    'slaves',
#    'army',
#    'exemptions',
#    'volunteers',
#    'negroes']),
#  ('/people/mr-william-elliot',
#   ['united',
#    'ireland',
#    'martial',
#    'law',
#    'us',
#    'majesty',
#    'information',
#    'ministers',
#    'sir',
#    'conspiracy']),
#  ('/people/lord-granville-leveson-gower',
#   ['received',
#    'three',
#    'county',
#    'volunteer',
#    'single',
#    'corps',
#    'ago',
#    'weeks',
#    'stafford',
#    'firelock']),
#  ('/people/mr-chapple-norton',
#   ['explained',
#    'defended',
#    'prosecution',
#    'details',
#    'incurred',
#    'adhered',
#    'expences',
#    'plans',
#    'completed',
#    'clashed']),
#  ('/people/sir-charles-pole',
#   ['memory',
#    'boats',
#    'toulon',
#    'rounds',
#    'treasurer',
#    'gun',
#    'naval',
#    'brest',
#    'wilson',
#    'commissioners']),
#  ('/people/mr-william-wilberforce-1',
#   ['importation',
#    'indies',
#    'west',
#    'gent',
#    'admiralty',
#    'hon',
#    'slave',
#    'trade',
#    'abolition',
#    'negroes']),
#  ('/people/mr-william-loftus',
#   ['counterpoise',
#    'volunteers',
#    'execution',
#    'coasts',
#    'precaution',
#    'grogan',
#    'magazines',
#    'cattle',
#    'driving',
#    'lake']),
#  ('/people/mr-henry-addington',
#   ['industrious',
#    'traced',
#    'grandfathers',
#    'subscriptions',
#    'learned',
#    'solitary',
#    'trade',
#    'gent',
#    'corps',
#    'spain']),
#  ('/people/mr-joseph-jekyll',
#   ['aquo',
#    'corporation',
#    'gent',
#    'calls',
#    'practice',
#    'challenge',
#    'specie',
#    'crowns',
#    'carmarthen',
#    'precedents']),
#  ('/people/mr-robert-deverell',
#   ['james',
#    'esq',
#    'presence',
#    'busines',
#    'accout',
#    'anygent',
#    'excusing',
#    'attendance',
#    'waterford',
#    'pedley']),
#  ('/people/mr-richard-ellison',
#   ['neither',
#    'bow',
#    'journals',
#    'signed',
#    'lincoln',
#    'resolutions',
#    'bend',
#    'militia',
#    'fydell',
#    'entry']),
#  ('/people/mr-george-berkeley',
#   ['frigates',
#    'marines',
#    'expense',
#    'contracts',
#    'averred',
#    'vessels',
#    'boats',
#    'barracks',
#    'admiralty',
#    'gun']),
#  ('/people/mr-robert-hurst-3',
#   ['impress',
#    'price',
#    'regulation',
#    'company',
#    'competition',
#    'marine',
#    'monopoly',
#    'estimates',
#    'bribery',
#    'beer']),
#  ('/people/mr-harvey-combe',
#   ['baker',
#    'compulsory',
#    'dealers',
#    'flour',
#    'simplify',
#    'civic',
#    'wholesale',
#    'price',
#    'bread',
#    'regulated']),
#  ('/people/mr-henry-thornton',
#   ['sir',
#    'procure',
#    'managers',
#    'poll',
#    'votes',
#    'divers',
#    'gifts',
#    'election',
#    'f',
#    'b']),
#  ('/people/sir-simon-newport',
#   ['morrow',
#    'tax',
#    'exchange',
#    'money',
#    'theirish',
#    'specie',
#    'timber',
#    'lunatics',
#    'wives',
#    'ireland']),
#  ('/people/lord-george-beresford',
#   ['commander',
#    'necessity',
#    'veracity',
#    'unite',
#    'renewed',
#    'burrows',
#    'remarkably',
#    'lower',
#    'thinness',
#    'enactment']),
#  ('/people/mr-thomas-grenville',
#   ['right',
#    'corps',
#    'force',
#    'act',
#    'majesty',
#    'reserve',
#    'volunteers',
#    'regular',
#    'army',
#    'ministers']),
#  ('/people/sir-robert-buxton-1',
#   ['default',
#    'cricklade',
#    'unequally',
#    'burthened',
#    'impolicy',
#    'seconded',
#    'livings',
#    'necessities',
#    'borough',
#    'curates']),
#  ('/people/mr-john-blaquiere',
#   ['hour',
#    'july',
#    'lord',
#    'x',
#    'hardwick',
#    'gentlemen',
#    'ireland',
#    'paving',
#    'blaquiere',
#    'board']),
#  ('/people/sir-thomas-metcalfe',
#   ['mah',
#    'ui',
#    'madajee',
#    'dowla',
#    'sujat',
#    'rattas',
#    'mahrattas',
#    'marquis',
#    'scindeah',
#    'extirpate']),
#  ('/people/lord-henry-petty',
#   ['sprott',
#    'exist',
#    'inquiry',
#    'te',
#    'ireland',
#    'broker',
#    'exchange',
#    'melville',
#    'bank',
#    'paper']),
#  ('/people/mr-william-best',
#   ['court',
#    'act',
#    'construction',
#    'rules',
#    'parliament',
#    'election',
#    'cargoes',
#    'petition',
#    'equitable',
#    'scott']),
#  ('/people/mr-john-fonblanque',
#   ['complied',
#    'respected',
#    'act',
#    'dash',
#    'pie',
#    'hardship',
#    'petition',
#    'mover',
#    'papers',
#    'aggrieved']),
#  ('/people/mr-robert-dallas',
#   ['preparation',
#    'culpable',
#    'conscientiously',
#    'information',
#    'neglect',
#    'contemptible',
#    'preparations',
#    'presents',
#    'lieut',
#    'govt']),
#  ('/people/sir-william-pulteney',
#   ['climate',
#    'negroes',
#    'warm',
#    'salt',
#    'islands',
#    'west',
#    'labour',
#    'trade',
#    'impost',
#    'slaves']),
#  ('/people/sir-john-wrottesley',
#   ['street',
#    'july',
#    'marsden',
#    'depot',
#    'magistrate',
#    'insurrection',
#    'lieutenant',
#    'rebellion',
#    'clock',
#    'government']),
#  ('/people/mr-richard-arden',
#   ['concurrence',
#    'entire',
#    'usually',
#    'morrow',
#    'woolsack',
#    'announced',
#    'applaud',
#    'walsingham',
#    'fort',
#    'routine']),
#  ('/people/mr-anthony-eyre',
#   ['terrified',
#    'overstrained',
#    'shots',
#    'flanders',
#    'thrill',
#    'peasantry',
#    'system',
#    'british',
#    'troops',
#    'german']),
#  ('/people/mr-samuel-whitbread-2',
#   ['hon',
#    'treasurer',
#    'gent',
#    'commissioners',
#    'money',
#    'public',
#    'mr',
#    'lord',
#    'trotter',
#    'melville']),
#  ('/people/sir-robert-lawley',
#   ['minuteness',
#    'wire',
#    'explicit',
#    'indisposition',
#    'health',
#    'adjourn',
#    'withdrawing',
#    'distressing',
#    'illness',
#    'inrolled']),
#  ('/people/mr-george-canning',
#   ['inquiry',
#    'army',
#    'noble',
#    'disposable',
#    'government',
#    'commissioners',
#    'hon',
#    'force',
#    'wilson',
#    'friend']),
#  ('/people/mr-charles-grey-1',
#   ['gent',
#    'hon',
#    'madrid',
#    'maj',
#    'govt',
#    'hawkesbury',
#    'neutrality',
#    'spanish',
#    'spain',
#    'frere']),
#  ('/people/mr-john-markham',
#   ['timber',
#    'repairs',
#    'insurance',
#    'hon',
#    'pamphlet',
#    'vincent',
#    'admiral',
#    'board',
#    'admiralty',
#    'navy']),
#  ('/people/mr-john-fuller',
#   ['troops',
#    'miles',
#    'slaves',
#    'hon',
#    'birch',
#    'orator',
#    'conveyance',
#    'negroes',
#    'counties',
#    'museum']),
#  ('/people/mr-george-johnstone',
#   ['prize',
#    'subsidy',
#    'sum',
#    'tax',
#    'france',
#    'scotland',
#    'millions',
#    'salt',
#    'frere',
#    'spain']),
#  ('/people/mr-walter-stanhope-1',
#   ['diseased',
#    'beacons',
#    'elder',
#    'dust',
#    'guilty',
#    'trotter',
#    'children',
#    'taxation',
#    'younger',
#    'tax']),
#  ('/people/mr-george-vansittart-1',
#   ['extending', 'imprisonment', 'fortnight']),
#  ('/people/mr-henry-lascelles-1',
#   ['expunged',
#    'wages',
#    'deduction',
#    'hill',
#    'balloted',
#    'accumulation',
#    'lax',
#    'altered',
#    'corn',
#    'farmers']),
#  ('/people/mr-john-atkins',
#   ['free',
#    'english',
#    'articles',
#    'duly',
#    'thirty',
#    'forty',
#    'imported',
#    'manufactures',
#    'manufacture',
#    'linen']),
#  ('/people/mr-charles-hawthorne',
#   ['four',
#    'schedule',
#    'increased',
#    'proportion',
#    'unfairly',
#    'accumulated',
#    'collectors',
#    'tax',
#    'grocers',
#    'licences']),
#  ('/people/mr-richard-archdall',
#   ['conducted',
#    'assumes',
#    'animus',
#    'recollecting',
#    'doctor',
#    'thee',
#    'badly',
#    'union',
#    'catholic',
#    'catholics']),
#  ('/people/mr-banastre-tarleton',
#   ['club',
#    'militia',
#    'seamen',
#    'feet',
#    'army',
#    'shed',
#    'corps',
#    'jacobinism',
#    'recruits',
#    'insubordination']),
#  ('/people/mr-john-proby-1',
#   ['doubtfully',
#    'incomes',
#    'medium',
#    'remedy',
#    'lordships',
#    'sustain',
#    'ireland',
#    'coin',
#    'resuming',
#    'bank']),
#  ('/people/lord-william-russell-1',
#   ['affluent',
#    'unfavourably',
#    'article',
#    'labouring',
#    'price',
#    'descriptions',
#    'sustenance',
#    'bread',
#    'tax',
#    'salt']),
#  ('/people/sir-john-anderson-1',
#   ['irish',
#    'admiral',
#    'hops',
#    'ordered',
#    'barrel',
#    'specifying',
#    'coals',
#    'corry',
#    'keith',
#    'stewart']),
#  ('/people/mr-charles-marsham',
#   ['votes',
#    'esq',
#    'witnesses',
#    'rawlins',
#    'walsh',
#    'cox',
#    'poll',
#    'evidence',
#    'counsel',
#    'sheriffs']),
#  ('/people/mr-joseph-western',
#   ['os',
#    'imported',
#    'property',
#    'bishops',
#    'average',
#    'church',
#    'fifth',
#    'corn',
#    'quantities',
#    'prices']),
#  ('/people/mr-william-pellew',
#   ['inside',
#    'manageable',
#    'brig',
#    'enemy',
#    'stationed',
#    'fleet',
#    'squadrons',
#    'ships',
#    'blockaded',
#    'gun']),
#  ('/people/mr-richard-sheridan-1',
#   ['may',
#    'yards',
#    'naval',
#    'men',
#    'say',
#    'friend',
#    'right',
#    'commissioners',
#    'hon',
#    'gent']),
#  ('/people/mr-george-ponsonby-1',
#   ['hon',
#    'corruption',
#    'arbitrary',
#    'public',
#    'shall',
#    'money',
#    'gent',
#    'lord',
#    'melville',
#    'trotter']),
#  ('/people/mr-william-sturges-bourne',
#   ['liberty',
#    'ships',
#    'yards',
#    'punishing',
#    'petitioner',
#    'admiralty',
#    'dictate',
#    'jury',
#    'accuser',
#    'societies']),
#  ('/people/mr-thomas-jones-2',
#   ['columns',
#    'bundle',
#    'camphor',
#    'welcomed',
#    'rivalled',
#    'nest',
#    'injure',
#    'admiral',
#    'motions',
#    'whisper']),
#  ('/people/sir-william-curtis',
#   ['unlucky',
#    'vigorously',
#    'breaches',
#    'trust',
#    'gross',
#    'outraged',
#    'aldermen',
#    'burthens',
#    'vessels',
#    'abuses']),
#  ('/people/mr-jonathan-raine',
#   ['ships',
#    'detention',
#    'negotiation',
#    'hostilities',
#    'nations',
#    'treasure',
#    'war',
#    'spanish',
#    'declaration',
#    'spain']),
#  ('/people/sir-william-geary-1',
#   ['commodity',
#    'wholesome',
#    'billingsgate',
#    'injury',
#    'fold',
#    'markets',
#    'fairly',
#    'cheapening',
#    'inexhaustible',
#    'monopoly']),
#  ('/people/lord-george-cavendish-1',
#   ['fathers',
#    'correspond',
#    'detached',
#    'fortunes',
#    'urging',
#    'postponing',
#    'legacies',
#    'property',
#    'inherited',
#    'industry']),
#  ('/people/mr-richard-ker-2',
#   ['tobacco',
#    'lengths',
#    'clamorous',
#    'brooding',
#    'gather',
#    'shone',
#    'tax',
#    'magistrates',
#    'export',
#    'sedition']),
#  ('/people/mr-john-latouche',
#   ['accomplishing',
#    'equal',
#    'population',
#    'weaken',
#    'merchants',
#    'ably',
#    'violent',
#    'enjoyments',
#    'catholics',
#    'constitution']),
#  ('/people/mr-james-brogden',
#   ['depress',
#    'exports',
#    'dublin',
#    'london',
#    'radically',
#    'draw',
#    'paucity',
#    'raided',
#    'redundance',
#    'instate']),
#  ('/people/mr-charles-ormsby',
#   ['reverting',
#    'clause',
#    'oft',
#    'rights',
#    'presentable',
#    'stirring',
#    'withed',
#    'lawyers',
#    'hereditary',
#    'crown']),
#  ('/people/mr-quintin-dick',
#   ['beresford',
#    'dent',
#    'ridan',
#    'restriction',
#    'mr',
#    'circuiting',
#    'quorum',
#    'brogden',
#    'medium',
#    'bank']),
#  ('/people/mr-george-spencer-2',
#   ['bill',
#    'repeal',
#    'lord',
#    'lordships',
#    'ldp',
#    'friend',
#    'frere',
#    'govt',
#    'ldps',
#    'noble']),
#  ('/people/mr-william-burroughs',
#   ['rights',
#    'osberved',
#    'heritable',
#    'popham',
#    'red',
#    'legislate',
#    'atholl',
#    'squadron',
#    'duke',
#    'compensation']),
#  ('/people/mr-charles-kinnaird',
#   ['sir',
#    'romney',
#    'repairs',
#    'report',
#    'downing',
#    'lordship',
#    'board',
#    'navy',
#    'vincent',
#    'hamond']),
#  ('/people/sir-john-frederick',
#   ['astley',
#    'jacob',
#    'lh',
#    'thehighway',
#    'imported',
#    'britain',
#    'quantity',
#    'billwas',
#    'malt',
#    'gt']),
#  ('/people/mr-william-cartwright-1',
#   ['breach',
#    'serve',
#    'lamented',
#    'avows',
#    'clogs',
#    'unseasonably',
#    'binds',
#    'prevents',
#    'fermentation',
#    'comes']),
#  ('/people/mr-nicolson-calvert',
#   ['scandalous',
#    'judicious',
#    'thousands',
#    'exceptionable',
#    'partizans',
#    'contrive',
#    'spend',
#    'jobbing',
#    'artifices',
#    'boroughs']),
#  ('/people/sir-home-popham',
#   ['fleet',
#    'admiralty',
#    'navy',
#    'officer',
#    'red',
#    'letter',
#    'pamphlet',
#    'julien',
#    'board',
#    'bartholomew']),
#  ('/people/sir-william-dolben',
#   ['let',
#    'fishermen',
#    'alledgment',
#    'corporation',
#    'catholics',
#    'firmly',
#    'society',
#    'seamen',
#    'nursery',
#    'marine']),
#  ('/people/mr-peter-moore',
#   ['frivolity',
#    'reexamined',
#    'birchall',
#    'abbreviate',
#    'rebut',
#    'sprat',
#    'mainwaring',
#    'burdett',
#    'votes',
#    'sheriffs']),
#  ('/people/mr-john-blackburn',
#   ['x',
#    'thought',
#    'bill',
#    'question',
#    'committee',
#    'ought',
#    'called',
#    'go',
#    'least',
#    'allowed']),
#  ('/people/sir-john-nicholl',
#   ['support',
#    'public',
#    'amount',
#    'asserted',
#    'crown',
#    'demand',
#    'coming',
#    'prizes',
#    'memorial',
#    'claimants']),
#  ('/people/mr-henry-bankes',
#   ['minister',
#    'refusal',
#    'contingent',
#    'spanish',
#    'treaty',
#    'armaments',
#    'ships',
#    'treasure',
#    'subsidy',
#    'spain']),
#  ('/people/mr-edward-law-1',
#   ['lords',
#    'spiritual',
#    'faith',
#    'ecclesiastical',
#    'religious',
#    'catholic',
#    'protestant',
#    'roman',
#    'church',
#    'lordships']),
#  ('/people/mr-john-parker-3',
#   ['inducement',
#    'sentiment',
#    'lordships',
#    'catholic',
#    'hastily',
#    'sensibility',
#    'catholics',
#    'concessions',
#    'roman',
#    'settlement']),
#  ('/people/mr-dudley-ryder',
#   ['fir',
#    'possible',
#    'removal',
#    'speedily',
#    'hawkesbury',
#    'muck',
#    'permament',
#    'abercorn',
#    'address',
#    'fox']),
#  ('/people/mr-charles-adams',
#   ['pusillanimity',
#    'goaded',
#    'overtures',
#    'seconding',
#    'safe',
#    'sir',
#    'swayed',
#    'adriatic',
#    'us',
#    'moments']),
#  ('/people/mr-james-stopford',
#   ['resolve',
#    'moved',
#    'pro',
#    'relates',
#    'forma',
#    'monday',
#    'palace',
#    'james',
#    'speaker',
#    'huskisson']),
#  ('/people/mr-henry-phipps',
#   ['documents',
#    'spanish',
#    'forbearance',
#    'maj',
#    'ldp',
#    'brit',
#    'noble',
#    'lordships',
#    'spain',
#    'govt']),
#  ('/people/mr-william-mitford-1',
#   ['esq',
#    'mainwaring',
#    'votes',
#    'election',
#    'f',
#    'aforesaid',
#    'burdett',
#    'sheriff',
#    'petitioners',
#    'poll']),
#  ('/people/mr-isaac-browne',
#   ['invidiously',
#    'worthily',
#    'animadverting',
#    'disbursed',
#    'wretches',
#    'cooke',
#    'commisioners',
#    'secret',
#    'sheriffs',
#    'emissaries']),
#  ('/people/mr-james-fitzgerald-1',
#   ['expences',
#    'loan',
#    'proportion',
#    'revenue',
#    'taxes',
#    'balances',
#    'debt',
#    'l',
#    'ireland',
#    'collectors']),
#  ('/people/mr-william-huskisson',
#   ['th',
#    'feb',
#    'amount',
#    'per',
#    'captain',
#    'cents',
#    'loan',
#    'scotland',
#    'bonus',
#    'l']),
#  ('/people/sir-evan-nepean',
#   ['corpus',
#    'jones',
#    'todd',
#    'stimulating',
#    'plots',
#    'comfortable',
#    'continuance',
#    'machinations',
#    'treasonable',
#    'irishmen']),
#  ('/people/lord-william-stuart',
#   ['martial',
#    'coldness',
#    'dispensably',
#    'assassin',
#    'courts',
#    'lists',
#    'loyal',
#    'circulating',
#    'regimental',
#    'govt']),
#  ('/people/mr-james-martin-1',
#   ['formalities',
#    'notoriety',
#    'martial',
#    'functionary',
#    'evidence',
#    'ireland',
#    'banks',
#    'cornelius',
#    'suspension',
#    'grogan']),
#  ('/people/mr-william-keppel',
#   ['rome',
#    'noble',
#    'protestant',
#    'discernment',
#    'lords',
#    'church',
#    'catholic',
#    'religion',
#    'universities',
#    'catholics']),
#  ('/people/mr-frederick-howard-1',
#   ['inefficient',
#    'earl',
#    'grand',
#    'preferable',
#    'absurd',
#    'imbecile',
#    'fair',
#    'accused',
#    'lords',
#    'noble']),
#  ('/people/mr-william-wellesley-pole',
#   ['office',
#    'g',
#    'forces',
#    'l',
#    'following',
#    'fid',
#    'brit',
#    'maj',
#    'estimates',
#    'ordnance']),
#  ('/people/mr-john-pratt-3',
#   ['amelioration',
#    'measure',
#    'reserve',
#    'numbers',
#    'men',
#    'army',
#    'force',
#    'raised',
#    'lordships',
#    'noble']),
#  ('/people/mr-robert-ward-1',
#   ['ventilators',
#    'prive',
#    'suspension',
#    'corpus',
#    'illustration',
#    'habeas',
#    'miseries',
#    'voyage',
#    'patriots',
#    'paragraph']),
#  ('/people/mr-william-bagwell',
#   ['militia',
#    'tain',
#    'assises',
#    'farm',
#    'bellowing',
#    'amend',
#    'relates',
#    'asylums',
#    'freeholds',
#    'wives']),
#  ('/people/mr-john-pytches',
#   ['ridden',
#    'dotage',
#    'froward',
#    'generated',
#    'cementing',
#    'nostrums',
#    'plaisters',
#    'gestation',
#    'gash',
#    'treat']),
#  ('/people/mr-isaac-gascoyne',
#   ['slaves',
#    'neighbouring',
#    'colonies',
#    'memory',
#    'planters',
#    'trade',
#    'blacks',
#    'colonial',
#    'negroes',
#    'abolition']),
#  ('/people/mr-robert-hobart',
#   ['munster',
#    'dissenter',
#    'protestant',
#    'leinster',
#    'noble',
#    'lordship',
#    'church',
#    'catholic',
#    'catholics',
#    'baron']),
#  ('/people/mr-richard-fitzpatrick',
#   ['clauses',
#    'years',
#    'propositions',
#    'enlistment',
#    'presidents',
#    'punishments',
#    'age',
#    'regimental',
#    'martial',
#    'courts']),
#  ('/people/mr-thomas-brooke',
#   ['facility',
#    'consular',
#    'navigate',
#    'powers',
#    'abolished',
#    'vessels',
#    'colonies',
#    'slave',
#    'france',
#    'trade']),
#  ('/people/mr-william-egerton-1',
#   ['pain',
#    'devise',
#    'burden',
#    'exemplary',
#    'alleviating',
#    'chester',
#    'deputed',
#    'northwich',
#    'cheshire',
#    'county']),
#  ('/people/mr-vicary-gibbs',
#   ['learned',
#    'burdett',
#    'election',
#    'mainwaring',
#    'hustings',
#    'silvester',
#    'mill',
#    'poll',
#    'voters',
#    'sheriffs']),
#  ('/people/mr-davies-giddy',
#   ['lived',
#    'fish',
#    'fisheries',
#    'detrimental',
#    'misery',
#    'substitution',
#    'wholly',
#    'curing',
#    'salt',
#    'tax']),
#  ('/people/mr-edward-smith-stanley',
#   ['objectionable',
#    'clock',
#    'informed',
#    'morning',
#    'extraordinary',
#    'secretary',
#    'saturday',
#    'adjourn',
#    'advanced',
#    'positions']),
#  ('/people/mr-hugh-fortescue',
#   ['refractory',
#    'mutiny',
#    'dismissal',
#    'hundred',
#    'earl',
#    'disturbances',
#    'names',
#    'artificers',
#    'yards',
#    'dock']),
#  ('/people/sir-eyre-coote',
#   ['age',
#    'propositions',
#    'cordially',
#    'discovery',
#    'truth',
#    'conducive',
#    'grateful',
#    'solemnity',
#    'martial',
#    'witnessess']),
#  ('/people/mr-james-langham',
#   ['approbation',
#    'terminated',
#    'seventh',
#    'untimely',
#    'vote',
#    'arty',
#    'ninth',
#    'biassing',
#    'commissioners',
#    'thanks']),
#  ('/people/mr-charles-stanhope',
#   ['helps',
#    'noble',
#    'arming',
#    'farmers',
#    'section',
#    'lordships',
#    'book',
#    'fence',
#    'indiscipline',
#    'prices']),
#  ('/people/mr-william-hughes-3',
#   ['variations',
#    'encroachments',
#    'destroyed',
#    'mortifications',
#    'appetite',
#    'illusions',
#    'harmless',
#    'disgusted',
#    'fencibles',
#    'militia']),
#  ('/people/mr-william-frankland',
#   ['militia',
#    'impolitic',
#    'transporting',
#    'welt',
#    'concentered',
#    'abate',
#    'critically',
#    'offensive',
#    'defensive',
#    'force']),
#  ('/people/mr-john-freeman-mitford-1',
#   ['church',
#    'priests',
#    'protestants',
#    'clergy',
#    'vicar',
#    'ireland',
#    'protestant',
#    'hierarchy',
#    'catholic',
#    'catholics']),
#  ('/people/mr-edward-lee',
#   ['debts',
#    'estates',
#    'protestant',
#    'notes',
#    'roman',
#    'religion',
#    'ireland',
#    'catholic',
#    'reformation',
#    'catholics']),
#  ('/people/mr-denis-daly',
#   ['several',
#    'oppose',
#    'bringing',
#    'morrow',
#    'adjourned',
#    'resolutions',
#    'reported',
#    'instructions',
#    'wait',
#    'constituents']),
#  ('/people/sir-george-hill',
#   ['rending',
#    'claims',
#    'proves',
#    'mover',
#    'rebellion',
#    'fitzwilliam',
#    'protestants',
#    'catholic',
#    'grattan',
#    'catholics']),
#  ('/people/sir-charles-price',
#   ['activity',
#    'compliment',
#    'unequivocally',
#    'criminality',
#    'market',
#    'magistrate',
#    'defer',
#    'capitals',
#    'discouraging',
#    'commerce']),
#  ('/people/lord-john-thynne',
#   ['keith',
#    'anne',
#    'bengal',
#    'creevey',
#    'innkeepers',
#    'bath',
#    'morrow',
#    'suffolk',
#    'brome',
#    'ipswich']),
#  ('/people/mr-charles-chapman',
#   ['supreme',
#    'mahrattas',
#    'chiefs',
#    'treaty',
#    'feudatory',
#    'berar',
#    'rajah',
#    'scindeah',
#    'holkar',
#    'peishwah']),
#  ('/people/mr-robert-thornton',
#   ['powers',
#    'olive',
#    'acted',
#    'sword',
#    'wellesley',
#    'native',
#    'conciliatory',
#    'india',
#    'marquis',
#    'lists']),
#  ('/people/mr-thomas-wallace-3',
#   ['communicate',
#    'communications',
#    'providing',
#    'incorrect',
#    'hamond',
#    'hobart',
#    'funds',
#    'earl',
#    'dune',
#    'assented']),
#  ('/people/mr-charles-moore-1',
#   ['ayes',
#    'noes',
#    'successors',
#    'countenanced',
#    'ensuing',
#    'malversation',
#    'mere',
#    'auditors',
#    'parishioners',
#    'job']),
#  ('/people/sir-john-hippisley',
#   ['palace',
#    'empower',
#    'needed',
#    'bank',
#    'curate',
#    'director',
#    'indictment',
#    'drafts',
#    'newland',
#    'trotter']),
#  ('/people/mr-claude-scott',
#   ['offered',
#    'treasury',
#    'money',
#    'paid',
#    'treasurer',
#    'sale',
#    'misinformed',
#    'bank',
#    'unemployed',
#    'settled']),
#  ('/people/sir-andrew-hamond',
#   ['vindication',
#    'letters',
#    'th',
#    'vincent',
#    'commissioners',
#    'board',
#    'admiralty',
#    'letter',
#    'navy',
#    'tucker']),
#  ('/people/mr-nathaniel-bond',
#   ['probandiwas',
#    'theclaves',
#    'insul',
#    'theonus',
#    'atholl',
#    'approbation',
#    'memorial',
#    'council',
#    'privy',
#    'duke']),
#  ('/people/mr-john-jeffery',
#   ['administration',
#    'earl',
#    'ships',
#    'papers',
#    'st',
#    'poole',
#    'vincent',
#    'navy',
#    'motions',
#    'launched']),
#  ('/people/mr-richard-ryder-1',
#   ['hesitate',
#    'convey',
#    'personally',
#    'petitioner',
#    'offences',
#    'libel',
#    'indebted',
#    'revive',
#    'animosities',
#    'extenuation']),
#  ('/people/mr-francis-brown',
#   ['dublin',
#    'friend',
#    'praise',
#    'streets',
#    'darkness',
#    'hardwicke',
#    'desolation',
#    'exclaimed',
#    'walking',
#    'imprests']),
#  ('/people/mr-francis-burton',
#   ['neighbourhood',
#    'officiated',
#    'hospitality',
#    'du',
#    'vicar',
#    'distributing',
#    'alms',
#    'marrying',
#    'visiting',
#    'rector']),
#  ('/people/mr-john-hutchinson-3',
#   ['misfortunes',
#    'ireland',
#    'chains',
#    'charity',
#    'distracted',
#    'code',
#    'prejudices',
#    'religion',
#    'protestant',
#    'catholic']),
#  ('/people/mr-henry-grattan',
#   ['empire',
#    'hate',
#    'rebellion',
#    'proscriptive',
#    'irish',
#    'church',
#    'protestant',
#    'religion',
#    'catholic',
#    'catholics']),
#  ('/people/mr-thomas-orde-powlett',
#   ['concession',
#    'reliance',
#    'good',
#    'separation',
#    'indulgences',
#    'may',
#    'conditional',
#    'remonstrance',
#    'catholic',
#    'catholics']),
#  ('/people/sir-john-sinclair-1',
#   ['preparing',
#    'admiralty',
#    'adviseable',
#    'embarrass',
#    'motions',
#    'juncture',
#    'accounts',
#    'multiplication',
#    'peruse',
#    'distracting']),
#  ('/people/sir-robert-shaw',
#   ['petition',
#    'irish',
#    'foe',
#    'sir',
#    'influence',
#    'shall',
#    'constituents',
#    'loyalty',
#    'dissenter',
#    'catholic']),
#  ('/people/mr-david-scott',
#   ['ascribing',
#    'intruding',
#    'turning',
#    'sir',
#    'scarce',
#    'faculty',
#    'virtue',
#    'severe',
#    'dean',
#    'offended']),
#  ('/people/sir-mark-wood',
#   ['merchandizes',
#    'goods',
#    'wood',
#    'duckworth',
#    'ship',
#    'vice',
#    'captain',
#    'admiral',
#    'memorialist',
#    'acasta']),
#  ('/people/mr-william-garrow',
#   ['charged',
#    'enquire',
#    'mistake',
#    'inevitably',
#    'lincoln',
#    'inn',
#    'inadvertency',
#    'excusable',
#    'ascribe',
#    'garrow']),
#  ('/people/mr-spencer-perceval',
#   ['tary',
#    'fields',
#    'noble',
#    'sp',
#    'abandoned',
#    'postponement',
#    'wednesday',
#    'perceval',
#    'printing',
#    'estimates']),
#  ('/people/sir-william-erskine',
#   ['devised',
#    'efficacious',
#    'devising',
#    'flourishing',
#    'army',
#    'anchor',
#    'raising',
#    'lesser',
#    'recompence',
#    'sheet']),
#  ('/people/mr-william-wickham-1',
#   ['prisoner',
#    'replying',
#    'liberate',
#    'prison',
#    'arrest',
#    'unconditional',
#    'irish',
#    'government',
#    'petitioner',
#    'jones']),
#  ('/people/mr-samuel-thornton',
#   ['corrupt',
#    'treasurer',
#    'evidence',
#    'herein',
#    'navel',
#    'employer',
#    'bank',
#    'newland',
#    'drafts',
#    'draft']),
#  ('/people/mr-george-capell-coningsby',
#   ['closest',
#    'condolence',
#    'commander',
#    'emperor',
#    'insert',
#    'germany',
#    'address',
#    'majesty',
#    'speech',
#    'lordships']),
#  ('/people/mr-peter-cowper',
#   ['majesty',
#    'purport',
#    'offer',
#    'allies',
#    'embracing',
#    'seconder',
#    'averting',
#    'abstaining',
#    'amendment',
#    'disasters'])]
